# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %% [markdown]
# mongoimport --type json -d uk_food -c establishments --file /Users/pcn08/ucb/homework/nosql-challenge/Module_12_Files/Resources/establishments.json --drop --jsonArray

# %% [markdown]
#  #Or try this one just in case
#
#  mongoimport --type json -d uk_food -c establishments --file establishments.json --drop --jsonArray

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name



db = mongo.uk_food_db
print(mongo.list_database_names())
# Out:
# ['admin', 'config', 'local', 'travel_db', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'uk_food')

# %%
# assign the collection to a variable
establishments = db['establishments']

# %%
# review the collections in our database
establishments = db.establishments
print(db.list_collection_names())
# Out:
# ['uk_food.establishments', 'establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
#query = {'scores': {'Hygiene': 20}}
#results= establishments.find(query)
#for result in results:
    #pprint(results)

# %%
# Find the establishments with a hygiene score of 20


# Use count_documents to display the number of documents in the result

# Display the first document in the results using pprint


query = {'scores.Hygiene': 20}
print("Establishments with a Hygiene score of 20:", establishments.count_documents(query))

print("First result:")
results = establishments.find(query)
pprint(results[0])
# Out:
# Establishments with a Hygiene score of 20: 41
# First result:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65bc3f5a3b481272ed133575'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.0},
# ...

# %%
# Convert the result to a Pandas DataFrame

# Display the number of rows in the DataFrame

# Display the first 10 rows of the DataFrame

see below

# %%
results = establishments.find(query)
# Convert the MongoDB query result to a Pandas DataFrame
hygiene_score_df = pd.DataFrame(list(results))

# Display the number of rows in the DataFrame
num_rows = len(hygiene_score_df)
print("Number of rows in the DataFrame:", num_rows)

# Display the first 10 rows of the DataFrame
print("First 10 rows of the DataFrame:")
hygiene_score_df.head(10)
# Out:
# Number of rows in the DataFrame: 41
# First 10 rows of the DataFrame:
#                         _id   FHRSID  ChangesByServerID  \
# 0  65bc3f5a3b481272ed133575   110681                  0
# 1  65bc3f5a3b481272ed1338f7   612039                  0
# 2  65bc3f5a3b481272ed133c06   730933                  0
# 3  65bc3f5a3b481272ed133dee   172735                  0
# 4  65bc3f5a3b481272ed133e00   172953                  0
# 5  65bc3f5a3b481272ed13479f   512854                  0
# 6  65bc3f5a3b481272ed1349c1  1537089                  0
# 7  65bc3f5a3b481272ed135ef8   155648                  0
# 8  65bc3f5a3b481272ed13632b  1012883                  0
# 9  65bc3f5a3b481272ed136b44   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
 # Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.

# Use count_documents to display the number of documents in the result

# Display the first document in the results using pprint

#Use regex

query = {
    'LocalAuthorityName':{'$regex':'London'},
    'RatingValue': {'$gte': 4}}
local_rating = establishments.count_documents(query)
print("Number of documents in the result:", local_rating) 

print("First document in the results:")
pprint(establishments.find_one(query))
# Out:
# Number of documents in the result: 33
# First document in the results:
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65bc3f5a3b481272ed134f91'),
# ...

# %%
# Convert the result to a Pandas DataFrame

# Display the number of rows in the DataFrame

# Display the first 10 rows of the DataFrame
#previous method didn't work so had to modify with this one.
results = establishments.find({
    'LocalAuthorityName':{'$regex':'London'},
    'RatingValue': {'$gte': 4}})
ratings_London_df=pd.DataFrame(results)
num_rows=ratings_London_df['_id'].count()
ratings_London_df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  65bc3f5a3b481272ed134f91   621707                  0
# 1  65bc3f5a3b481272ed1352b5  1130836                  0
# 2  65bc3f5a3b481272ed135e05   293783                  0
# 3  65bc3f5a3b481272ed136c04  1315095                  0
# 4  65bc3f5a3b481272ed136c06   294474                  0
# 5  65bc3f5a3b481272ed13730c   294900                  0
# 6  65bc3f5b3b481272ed13942e   293756                  0
# 7  65bc3f5b3b481272ed1397f8   878523                  0
# 8  65bc3f5b3b481272ed1397fe   293772                  0
# 9  65bc3f5b3b481272ed1397ff   294606                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000036464  Coombs Catering t/a The Lock and Key
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
#Find the restaurant to get geocode
establishments.find_one({"BusinessName": "Penang Flavours"})
# Out:
# {'_id': ObjectId('65bc4d90eab55afa0e2bb833'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 0.0, 'latitude': 51.490142},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True,
#  'longitude': None,
#  'RatingValue': None}

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.49014
longitude = 0.0

query = {
    'geocode.latitude': {'$gte': latitude - degree_search, '$lte': latitude + degree_search},
    'geocode.longitude': {'$gte': longitude - degree_search, '$lte': longitude + degree_search},
    'RatingValue': 5
}
sort =  [('HygieneScore', 1)]

# Print the results
results=list(establishments.find(query).sort(sort).limit(5))
pprint(results)
# Out:
# [{'AddressLine1': 'Shop 1',
#   'AddressLine2': 'Gloucester Avenue',
#   'AddressLine3': 'East Tilbury',
#   'AddressLine4': 'Essex',
#   'BusinessName': 'Essex Chef',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4634.793541689465,
#   'FHRSID': 931030,
#   'LocalAuthorityBusinessID': '16/00155/CP',
#   'LocalAuthorityCode': '894',
#   'LocalAuthorityEmailAddress': 'foodsafety@thurrock.gov.uk',
#   'LocalAuthorityName': 'Thurrock',
#   'LocalAuthorityWebSite': 'http://www.thurrock.gov.uk/food',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'RM18 8RB',
#   'RatingDate': '2021-02-13T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65bc3f5a3b481272ed136528'),
#   'geocode': {'latitude': 51.4804524, 'longitude': 0.0},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/931030',
# ...

# %%
# Convert result to Pandas DataFrame
results=list(establishments.find(query).sort(sort).limit(5))

geocode_score_df = pd.DataFrame(list(results))

geocode_score_df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  65bc3f5a3b481272ed136528   931030                  0
# 1  65bc3f5a3b481272ed136575   390327                  0
# 2  65bc3f5a3b481272ed1364fb  1077306                  0
# 3  65bc3f5a3b481272ed1364fe   706095                  0
# 4  65bc3f5a3b481272ed136570  1453706                  0
#
#   LocalAuthorityBusinessID                  BusinessName  \
# 0              16/00155/CP                    Essex Chef
# 1              07/00090/CP  Chelmsford Star Co-operative
# 2              18/00156/CP                         Preem
# 3              14/00114/CP          Cheers Food And Wine
# 4              22/00016/CP             George's Fish Bar
#
#                             BusinessType  BusinessTypeID  \
# 0                 Takeaway/sandwich shop            7844
# 1  Retailers - supermarkets/hypermarkets            7840
# 2                 Takeaway/sandwich shop            7844
# ...

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

# Print the number of documents in the result

# Print the first 10 results
pipeline = [
    # Match establishments with a hygiene score of 0
    {'$match': {'scores.Hygiene': 0}},
    # Group by Local Authority
    {'$group': {'_id': '$LocalAuthorityName', 'count': {'$sum': 1}}},
    # Sort the groups from highest to lowest
    {'$sort': {'count': -1}}
]

query = list(establishments.aggregate(pipeline))

# Print the number of documents in the result
print("Local Authority area establishments that have a hygiene score of 0:", len(query))

pprint(query[0:10])
# Out:
# Local Authority area establishments that have a hygiene score of 0: 55
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
results = list(establishments.aggregate(pipeline))
# Convert the result to a Pandas DataFrame
pipeline_hygiene_df = pd.DataFrame(list(results))

# Display the number of rows in the DataFrame
num_rows = len(pipeline_hygiene_df)
print("Number of rows in the DataFrame:", num_rows)

# Display the first 10 rows of the DataFrame
print("First 10 rows of the DataFrame:")
hygiene_score_df.head(10)
# Out:
# Number of rows in the DataFrame: 55
# First 10 rows of the DataFrame:
#                         _id   FHRSID  ChangesByServerID  \
# 0  65bc3f5a3b481272ed133575   110681                  0
# 1  65bc3f5a3b481272ed1338f7   612039                  0
# 2  65bc3f5a3b481272ed133c06   730933                  0
# 3  65bc3f5a3b481272ed133dee   172735                  0
# 4  65bc3f5a3b481272ed133e00   172953                  0
# 5  65bc3f5a3b481272ed13479f   512854                  0
# 6  65bc3f5a3b481272ed1349c1  1537089                  0
# 7  65bc3f5a3b481272ed135ef8   155648                  0
# 8  65bc3f5a3b481272ed13632b  1012883                  0
# 9  65bc3f5a3b481272ed136b44   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# ...
